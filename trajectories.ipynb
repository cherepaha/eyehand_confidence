# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('figure', dpi=200)

import data_reader, trajectory_plotter

dr = data_reader.DataReader()
tp = trajectory_plotter.TrajectoryPlotter()

choices, dynamics, gamble = dr.get_data(path='../../data/HEM_AK/processed/')

# %%
trial = random.choice(choices[~choices.is_com].index)
tp.plot_trajectory_xy(dynamics.loc[trial])

# %%
trial = random.choice(choices[choices.is_com].index)
tp.plot_trajectory_xy(dynamics.loc[trial])

# %%
trials = choices[choices.subj_id==132].index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-d0b9c544eef5> in <module>()
# ----> 1 trials = choices[choices.subj_id==132].index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'subj_id'
